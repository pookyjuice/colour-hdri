# %% [markdown]
# # Colour - HDRI - Examples: Advanced Processing with the Node-Graph

# %% [markdown]
# In this example, some Canon EOS 5D Mark II *CR2* images will be processed using the node-graph.
#
# The following dependencies are required:
#
# - [rawpy](https://pypi.org/project/rawpy)
# - [lensfunpy](https://pypi.org/project/lensufnpy)
# - [colour-datasets](https://pypi.org/project/colour-datasets)
# - [Adobe DNG Converter](https://helpx.adobe.com/camera-raw/using/adobe-dng-converter.html) (or [dnglab](https://github.com/dnglab/dnglab) on Linux)

# %%
import logging
import multiprocessing
import numpy as np
import os

import rawpy
from IPython.display import SVG

import colour
import colour_datasets

from colour_hdri import (
    ROOT_RESOURCES_EXAMPLES,
    GraphBatchMergeHDRI,
    GraphHDRI,
    GraphMergeHDRI,
    GraphPostMergeHDRI,
    GraphRawProcessingDNG,
    GraphRawProcessingCameraSensitivities,
    filter_files,
)
from colour_hdri.plotting import plot_HDRI_strip

# Rawpy crashes when ran from multiprocessing in a Docker container.
multiprocessing.set_start_method("spawn")

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(process)d - %(levelname)s - %(message)s",
)

ROOT_RESOURCES = os.path.join(ROOT_RESOURCES_EXAMPLES, "frobisher_001")

colour.plotting.colour_style()

colour.utilities.set_default_float_dtype(np.float32)

colour.utilities.describe_environment();
# Out:
# ===============================================================================
# *                                                                             *
# *   Interpreter :                                                             *
# *       python : 3.12.6 (main, Sep  9 2024, 21:36:32) [Clang 18.1.8 ]         *
# *                                                                             *
# *   colour-science.org :                                                      *
# *       colour : v0.2.5-20-g2ebc78c                                           *
# *       colour-datasets : v0.2.5-20-g2ebc78c                                  *
# *       colour-hdri : v0.2.5-20-g2ebc78c                                      *
# *                                                                             *
# *   Runtime :                                                                 *
# *       imageio : 2.36.0                                                      *
# *       matplotlib : 3.9.2                                                    *
# *       networkx : 3.4.1                                                      *
# *       numpy : 1.26.4                                                        *
# *       pydot : 3.0.2                                                         *
# *       scipy : 1.14.1                                                        *
# *       tqdm : 4.66.5                                                         *
# *       OpenImageIO : 2.5.16.0                                                *
# *       rawpy : 0.23.1                                                        *
# *       lensfunpy : 1.15.0                                                    *
# *       OpenCV : 4.10.0                                                       *
# *                                                                             *
# ===============================================================================

# %% [markdown]
# ## Raw Files Filtering

# %%
RAW_FILES = filter_files(ROOT_RESOURCES, ("CR2",))

# %%
def read_raw_file_preview(path):  # noqa: D103
    raw = rawpy.imread(path).postprocess(
        gamma=(1, 1), no_auto_bright=True, output_bps=16
    )

    return colour.utilities.as_float_array(raw) / 65535


colour.plotting.plot_image(
    colour.cctf_encoding(
        read_raw_file_preview(RAW_FILES[-2])[1400:2400, 3200:4200, ...]
    ),
    text_kwargs={"text": os.path.basename(RAW_FILES[-2])},
);

# %% [markdown]
# ## Processing a Single Image (DNG)

# %%
graph = GraphRawProcessingDNG()
SVG(graph.to_graphviz().create_svg())

# %%
raw_file_path = RAW_FILES[-2]

graph.set_input("raw_file_path", raw_file_path)
graph.set_input("output_file_path", raw_file_path.replace(".CR2", ".exr"))

graph.process()

colour.plotting.plot_image(
    colour.cctf_encoding(colour.read_image(graph.get_output("output")))
);
# Out:
# 2024-10-16 21:01:30,597 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeConvertRawFileToDNGFile#2(None)" node...
# 2024-10-16 21:01:30,600 - 19717 - INFO - Converting "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.CR2" file to "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.dng" file.
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# 2024-10-16 21:01:31,385 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeReadFileMetadataDNG#3(None)" node...
# 2024-10-16 21:01:31,388 - 19717 - INFO - Reading "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.dng" image EXIF data.
# 2024-10-16 21:01:31,599 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeComputeInputTransformDNG#4(None)" node...
# 2024-10-16 21:01:31,601 - 19717 - INFO - ComputeInputTransformDNG: As Shot Neutral (EXIF): [ 0.41307   1.        0.646465]
# 2024-10-16 21:01:31,602 - 19717 - INFO - ComputeInputTransformDNG: Camera Neutral: [ 6500.     0.]
# 2024-10-16 21:01:31,612 - 19717 - INFO - ComputeInputTransformDNG: Camera Neutral "CIE xy" chromaticity coordinates: [ 0.3135269   0.32362998]
# 2024-10-16 21:01:31,655 - 19717 - INFO - ComputeInputTransformDNG: Camera Neutral "CCT": [ 6500.0063        nan]
# 2024-10-16 21:01:31,664 - 19717 - INFO - ComputeInputTransformDNG: "CIE XYZ D50" to "Camera Space" matrix "M": [[ 0.45288221  0.05789947 -0.07970097]
#  [-0.77978706  1.54738164  0.24800709]
#  [-0.144568    0.18718591  0.64275275]]
# 2024-10-16 21:01:31,693 - 19717 - INFO - ComputeInputTransformDNG: White balance multipliers "RGB": [ 2.6271377  1.         1.3936511]
# 2024-10-16 21:01:31,711 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeProcessRawFileRawpy#5(None)" node...
# 2024-10-16 21:01:31,718 - 19717 - INFO - ProcessRawFileRawpy: Processing "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.dng" file...
# 2024-10-16 21:01:43,687 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeRemoveFile#6(None)" node...
# 2024-10-16 21:01:43,698 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeCorrectLensAberrationLensFun#7(None)" node...
# 2024-10-16 21:01:43,799 - 19717 - INFO - CorrectLensAberrationLensFun: Searching for "Canon" "Canon EOS 5D Mark II" camera model.
# 2024-10-16 21:01:43,814 - 19717 - INFO - CorrectLensAberrationLensFun: Using "Camera(Maker: Canon; Model: Canon EOS 5D Mark II; Mount: Canon EF; Crop Factor: 1.0; Score: 200)" camera for lens aberrations correction.
# 2024-10-16 21:01:43,821 - 19717 - INFO - CorrectLensAberrationLensFun: Searching for "EF16-35mm f/2.8L II USM" lens model.
# 2024-10-16 21:01:43,836 - 19717 - INFO - CorrectLensAberrationLensFun: Using "Lens(Maker: Canon; Model: Canon EF 16-35mm f/2.8L II USM; Type: RECTILINEAR; Focal: 16.0-35.0; Aperture: 2.799999952316284-22.0; Crop factor: 1.0; Score: 52)" lens for lens aberrations correction.
# 2024-10-16 21:01:43,854 - 19717 - INFO - CorrectLensAberrationLensFun: Correcting lens vignette...
# 2024-10-16 21:01:44,023 - 19717 - INFO - CorrectLensAberrationLensFun: Lens vignette was successfully corrected!
# 2024-10-16 21:01:44,028 - 19717 - INFO - CorrectLensAberrationLensFun: Correcting lens chromatic aberration...
# 2024-10-16 21:01:45,296 - 19717 - INFO - CorrectLensAberrationLensFun: Lens chromatic aberration was successfully corrected!
# 2024-10-16 21:01:45,303 - 19717 - INFO - CorrectLensAberrationLensFun: Correcting lens distortion...
# 2024-10-16 21:01:45,704 - 19717 - INFO - CorrectLensAberrationLensFun: Lens distortion was successfully corrected!
# 2024-10-16 21:01:45,713 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeDownsample#8(None)" node...
# 2024-10-16 21:01:45,717 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeApplyInputTransformDNG#9(None)" node...
# 2024-10-16 21:01:49,156 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeProcessingMetadata#10(None)" node...
# 2024-10-16 21:01:49,162 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeWatermark#11(None)" node...
# 2024-10-16 21:01:49,262 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeOrient#12(None)" node...
# 2024-10-16 21:01:49,264 - 19717 - INFO - GraphRawProcessingDNG: Processing "NodeWriteImage#13(None)" node...

# %% [markdown]
# ## Processing a Single Image (Camera Sensitivities)

# %%
print(colour_datasets.datasets())

DATABASE_SENSITIVITIES = colour.utilities.CanonicalMapping(
    {
        "canon-eos-5d-mark-ii": colour_datasets.load("3372171")["camera"][
            "canon eos 5d mark ii"
        ]
    }
)

print(list(DATABASE_SENSITIVITIES.keys()))
# Out:
# colour-science-datasets
# =======================
#
# Datasets : 23
# Synced   : 2
# URL      : https://zenodo.org/communities/colour-science-datasets
#
# Datasets
# --------
#
# [ ] 3269926 : Agfa IT8.7/2 Set - Marszalec (n.d.)
# [ ] 8314702 : Camera Dataset - Solomatov and Akkaynak (2023)
# [ ] 3245883 : Camera Spectral Sensitivity Database - Jiang et al. (2013)
# [ ] 3367463 : Constant Hue Loci Data - Hung and Berns (1995)
# [ ] 3362536 : Constant Perceived-Hue Data - Ebner and Fairchild (1998)
# [ ] 3270903 : Corresponding-Colour Datasets - Luo and Rhodes (1999)
# [ ] 3269920 : Forest Colors - Jaaskelainen et al. (1994)
# [ ] 4394536 : LUTCHI Colour Appearance Data - Luo and Rhodes (1997)
# [x] 3245875 : Labsphere SRS-99-020 - Labsphere (2019)
# [ ] 3269924 : Lumber Spectra - Hiltunen (n.d.)
# [ ] 4051012 : Measured Commercial LED Spectra - Brendel (2020)
# [ ] 3269918 : Munsell Colors Glossy (All) (Spectrofotometer Measured) - Orava (n.d.)
# [ ] 3269916 : Munsell Colors Glossy (Spectrofotometer Measured) - Haanpalo (n.d.)
# [ ] 3269914 : Munsell Colors Matt (AOTF Measured) - Hauta-Kasari (n.d.)
# [ ] 3269912 : Munsell Colors Matt (Spectrofotometer Measured) - Hauta-Kasari (n.d.)
# [x] 3245895 : New Color Specifications for ColorChecker SG and Classic Charts - X-Rite (2016)
# [ ] 3252742 : Observer Function Database - Asano (2015)
# [ ] 3269922 : Paper Spectra - Haanpalo (n.d.)
# [ ] 6590768 : Physlight - Camera Spectral Sensitivity Curves - Winquist et al. (2022)
# [ ] 3372171 : RAW to ACES Utility Data - Dyer et al. (2017)
# [ ] 4642271 : Spectral Database of Commonly Used Cine Lighting - Karge et al. (2015)
# [ ] 4297288 : Spectral Sensitivity Database - Zhao et al. (2009)
# [ ] 4050598 : Spectral Upsampling Coefficient Tables - Jakob and Hanika. (2019)
# Pulling "RAW to ACES Utility Data - Dyer et al. (2017)" record content...
# Downloading "https://zenodo.org/api/records/3372171/files/data.zip/content" url: 115kB [00:01, 75.1kB/s]
# Unpacking "/Users/kelsolaar/.colour-science/colour-datasets/3372171/dataset/data.zip" archive...
# ['canon-eos-5d-mark-ii']

# %%
graph = GraphRawProcessingCameraSensitivities()
SVG(graph.to_graphviz().create_svg())

# %%
raw_file_path = RAW_FILES[-2]

graph.set_input("raw_file_path", raw_file_path)
graph.set_input("output_file_path", raw_file_path.replace(".CR2", ".exr"))
graph.set_input("camera_sensitivities", DATABASE_SENSITIVITIES)

graph.process()

colour.plotting.plot_image(
    colour.cctf_encoding(colour.read_image(graph.get_output("output")))
);
# Out:
# 2024-10-16 21:02:02,721 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeConvertRawFileToDNGFile#15(None)" node...
# 2024-10-16 21:02:02,724 - 19717 - INFO - Converting "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.CR2" file to "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.dng" file.
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# 2024-10-16 21:02:03,547 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeReadFileMetadataDNG#16(None)" node...
# 2024-10-16 21:02:03,552 - 19717 - INFO - Reading "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.dng" image EXIF data.
# 2024-10-16 21:02:03,755 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeComputeInputTransformCameraSensitivities#17(None)" node...
# 2024-10-16 21:02:03,756 - 19717 - INFO - ComputeInputTransformCameraSensitivities: Using "Canon EOS 5D Mark II" camera model sensitivities.
# 2024-10-16 21:02:03,757 - 19717 - INFO - ComputeInputTransformCameraSensitivities: Using "Daylight" illuminant!
# 2024-10-16 21:02:04,094 - 19717 - INFO - ComputeInputTransformCameraSensitivities: Input Transform Matrix: [[ 0.8612217  -0.01401138  0.15278971]
#  [ 0.05936895  1.149629   -0.20899796]
#  [ 0.02250594 -0.19228421  1.1697782 ]]
# 2024-10-16 21:02:04,097 - 19717 - INFO - ComputeInputTransformCameraSensitivities: White balance multipliers "RGB": [ 2.5270655  1.         1.3662274]
# 2024-10-16 21:02:04,098 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeProcessRawFileRawpy#18(None)" node...
# 2024-10-16 21:02:04,101 - 19717 - INFO - ProcessRawFileRawpy: Processing "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.dng" file...
# 2024-10-16 21:02:15,747 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeRemoveFile#19(None)" node...
# 2024-10-16 21:02:15,751 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeCorrectLensAberrationLensFun#20(None)" node...
# 2024-10-16 21:02:15,843 - 19717 - INFO - CorrectLensAberrationLensFun: Searching for "Canon" "Canon EOS 5D Mark II" camera model.
# 2024-10-16 21:02:15,852 - 19717 - INFO - CorrectLensAberrationLensFun: Using "Camera(Maker: Canon; Model: Canon EOS 5D Mark II; Mount: Canon EF; Crop Factor: 1.0; Score: 200)" camera for lens aberrations correction.
# 2024-10-16 21:02:15,868 - 19717 - INFO - CorrectLensAberrationLensFun: Searching for "EF16-35mm f/2.8L II USM" lens model.
# 2024-10-16 21:02:15,875 - 19717 - INFO - CorrectLensAberrationLensFun: Using "Lens(Maker: Canon; Model: Canon EF 16-35mm f/2.8L II USM; Type: RECTILINEAR; Focal: 16.0-35.0; Aperture: 2.799999952316284-22.0; Crop factor: 1.0; Score: 52)" lens for lens aberrations correction.
# 2024-10-16 21:02:15,891 - 19717 - INFO - CorrectLensAberrationLensFun: Correcting lens vignette...
# 2024-10-16 21:02:16,062 - 19717 - INFO - CorrectLensAberrationLensFun: Lens vignette was successfully corrected!
# 2024-10-16 21:02:16,064 - 19717 - INFO - CorrectLensAberrationLensFun: Correcting lens chromatic aberration...
# 2024-10-16 21:02:17,012 - 19717 - INFO - CorrectLensAberrationLensFun: Lens chromatic aberration was successfully corrected!
# 2024-10-16 21:02:17,013 - 19717 - INFO - CorrectLensAberrationLensFun: Correcting lens distortion...
# 2024-10-16 21:02:17,403 - 19717 - INFO - CorrectLensAberrationLensFun: Lens distortion was successfully corrected!
# 2024-10-16 21:02:17,413 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeDownsample#21(None)" node...
# 2024-10-16 21:02:17,418 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeApplyInputTransformCameraSensitivities#22(None)" node...
# 2024-10-16 21:02:19,369 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeProcessingMetadata#23(None)" node...
# 2024-10-16 21:02:19,375 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeWatermark#24(None)" node...
# 2024-10-16 21:02:19,496 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeOrient#25(None)" node...
# 2024-10-16 21:02:19,500 - 19717 - INFO - GraphRawProcessingCameraSensitivities: Processing "NodeWriteImage#26(None)" node...

# %% [markdown]
# ## Processing and Merging Multiple Images to HDRI

# %% [markdown]
# The graph used to process and merge multiple images to HDRI is complex and uses multiple nested sub-graphs and parallel for loops leveraging multiprocessing:
#
# - `GraphHDRI`
#     - Loop Output: `GraphRawProcessingCameraSensitivities`
#     - Execution Output: `GraphBatchMergeHDRI`
#         - Loop Output: `GraphMergeHDRI`
#         - Execution Output: `GraphPostMergeHDR`

# %%
SVG(GraphHDRI().to_graphviz().create_svg())

# %%
SVG(GraphBatchMergeHDRI().to_graphviz().create_svg())

# %%
SVG(GraphMergeHDRI().to_graphviz().create_svg())

# %%
SVG(GraphPostMergeHDRI().to_graphviz().create_svg())

# %%
graph = GraphHDRI()
graph.set_input("array", RAW_FILES)
graph.set_input("camera_sensitivities", DATABASE_SENSITIVITIES)
graph.set_input("batch_size", 5)
graph.process()

plot_HDRI_strip(colour.read_image(graph.get_output("output")[0][0]))

colour.plotting.plot_image(colour.read_image(graph.get_output("output")[0][1]));
# Out:
# 2024-10-16 21:02:25,757 - 19717 - INFO - GraphHDRI: Processing "ParallelForMultiprocess#82(None)" node...
# 2024-10-16 21:02:25,758 - 19717 - INFO - ParallelForMultiprocess: Processing "GraphRawProcessingCameraSensitivities(12)" node...
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# *** GPU Warning: GPU3 disabled via cr_config at init time. ***
# 2024-10-16 22:00:17,339 - 19717 - INFO - ParallelForMultiprocess: Processed "('/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2598.exr', CanonicalMapping({'EXIF': CanonicalMapping({'Make': 'Canon', 'Camera Model Name': 'Canon EOS 5D Mark II', 'Camera Serial Number': '330229410', 'Lens Model': 'EF16-35mm f/2.8L II USM', 'DNG Lens Info': '16 35 undef undef', 'Focal Length': 16.0, 'Exposure Time': 0.002, 'F Number': 8.0, 'ISO': 100.0, 'CFA Pattern 2': array([0, 1, 1, 2]), 'CFA Plane Color': array([0, 1, 2]), 'Black Level Repeat Dim': array([2, 2]), 'Black Level': array([1023, 1023, 1023, 1023]), 'White Level': array([15600]), 'Samples Per Pixel': 3, 'Active Area': array([  51,  158, 3804, 5792]), 'Orientation': 1, 'Camera Calibration Sig': 'com.adobe', 'Profile Calibration Sig': 'com.adobe', 'Calibration Illuminant 1': 17, 'Calibration Illuminant 2': 21, 'Color Matrix 1': array([[ 0.5309, -0.0229, -0.0336],
#        [-0.6241,  1.3265,  0.3337],
#        [-0.0817,  0.1215,  0.6664]]), 'Color Matrix 2': array([[ 0.4716,  0.0603, -0.083 ],
#        [-0.7798,  1.5474,  0.248 ],
#        [-0.1496,  0.1937,  0.6651]]), 'Camera Calibration 1': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Camera Calibration 2': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Analog Balance': array([ 1.,  1.,  1.]), 'Reduction Matrix 1': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Reduction Matrix 2': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Forward Matrix 1': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'Forward Matrix 2': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'As Shot Neutral': array([ 0.41307 ,  1.      ,  0.646465]), 'Baseline Exposure': 0.40000000000000002, 'Baseline Noise': 0.80000000000000004})}), InputTransform(M=array([[ 0.86482609, -0.01870308,  0.15387699],
#        [ 0.06217639,  1.14592314, -0.20809953],
#        [ 0.02503111, -0.1967513 ,  1.17172019]]), RGB_w=array([ 2.52706552,  1.        ,  1.36622751])), 'sRGB')" element with index "0".
# 2024-10-16 22:17:20,025 - 19717 - INFO - ParallelForMultiprocess: Processed "('/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2599.exr', CanonicalMapping({'EXIF': CanonicalMapping({'Make': 'Canon', 'Camera Model Name': 'Canon EOS 5D Mark II', 'Camera Serial Number': '330229410', 'Lens Model': 'EF16-35mm f/2.8L II USM', 'DNG Lens Info': '16 35 undef undef', 'Focal Length': 16.0, 'Exposure Time': 0.01666666667, 'F Number': 8.0, 'ISO': 100.0, 'CFA Pattern 2': array([0, 1, 1, 2]), 'CFA Plane Color': array([0, 1, 2]), 'Black Level Repeat Dim': array([2, 2]), 'Black Level': array([1023, 1023, 1023, 1023]), 'White Level': array([15600]), 'Samples Per Pixel': 3, 'Active Area': array([  51,  158, 3804, 5792]), 'Orientation': 1, 'Camera Calibration Sig': 'com.adobe', 'Profile Calibration Sig': 'com.adobe', 'Calibration Illuminant 1': 17, 'Calibration Illuminant 2': 21, 'Color Matrix 1': array([[ 0.5309, -0.0229, -0.0336],
#        [-0.6241,  1.3265,  0.3337],
#        [-0.0817,  0.1215,  0.6664]]), 'Color Matrix 2': array([[ 0.4716,  0.0603, -0.083 ],
#        [-0.7798,  1.5474,  0.248 ],
#        [-0.1496,  0.1937,  0.6651]]), 'Camera Calibration 1': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Camera Calibration 2': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Analog Balance': array([ 1.,  1.,  1.]), 'Reduction Matrix 1': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Reduction Matrix 2': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Forward Matrix 1': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'Forward Matrix 2': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'As Shot Neutral': array([ 0.41307 ,  1.      ,  0.646465]), 'Baseline Exposure': 0.40000000000000002, 'Baseline Noise': 0.80000000000000004})}), InputTransform(M=array([[ 0.86482609, -0.01870308,  0.15387699],
#        [ 0.06217639,  1.14592314, -0.20809953],
#        [ 0.02503111, -0.1967513 ,  1.17172019]]), RGB_w=array([ 2.52706552,  1.        ,  1.36622751])), 'sRGB')" element with index "1".
# 2024-10-16 22:17:22,342 - 19717 - INFO - ParallelForMultiprocess: Processed "('/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2602.exr', CanonicalMapping({'EXIF': CanonicalMapping({'Make': 'Canon', 'Camera Model Name': 'Canon EOS 5D Mark II', 'Camera Serial Number': '330229410', 'Lens Model': 'EF16-35mm f/2.8L II USM', 'DNG Lens Info': '16 35 undef undef', 'Focal Length': 16.0, 'Exposure Time': 8.0, 'F Number': 8.0, 'ISO': 100.0, 'CFA Pattern 2': array([0, 1, 1, 2]), 'CFA Plane Color': array([0, 1, 2]), 'Black Level Repeat Dim': array([2, 2]), 'Black Level': array([1023, 1023, 1023, 1023]), 'White Level': array([15600]), 'Samples Per Pixel': 3, 'Active Area': array([  51,  158, 3804, 5792]), 'Orientation': 1, 'Camera Calibration Sig': 'com.adobe', 'Profile Calibration Sig': 'com.adobe', 'Calibration Illuminant 1': 17, 'Calibration Illuminant 2': 21, 'Color Matrix 1': array([[ 0.5309, -0.0229, -0.0336],
#        [-0.6241,  1.3265,  0.3337],
#        [-0.0817,  0.1215,  0.6664]]), 'Color Matrix 2': array([[ 0.4716,  0.0603, -0.083 ],
#        [-0.7798,  1.5474,  0.248 ],
#        [-0.1496,  0.1937,  0.6651]]), 'Camera Calibration 1': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Camera Calibration 2': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Analog Balance': array([ 1.,  1.,  1.]), 'Reduction Matrix 1': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Reduction Matrix 2': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Forward Matrix 1': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'Forward Matrix 2': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'As Shot Neutral': array([ 0.41307 ,  1.      ,  0.646465]), 'Baseline Exposure': 0.40000000000000002, 'Baseline Noise': 0.80000000000000004})}), InputTransform(M=array([[ 0.86482609, -0.01870308,  0.15387699],
#        [ 0.06217639,  1.14592314, -0.20809953],
#        [ 0.02503111, -0.1967513 ,  1.17172019]]), RGB_w=array([ 2.52706552,  1.        ,  1.36622751])), 'sRGB')" element with index "4".
# 2024-10-16 22:17:22,998 - 19717 - INFO - ParallelForMultiprocess: Processed "('/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2600.exr', CanonicalMapping({'EXIF': CanonicalMapping({'Make': 'Canon', 'Camera Model Name': 'Canon EOS 5D Mark II', 'Camera Serial Number': '330229410', 'Lens Model': 'EF16-35mm f/2.8L II USM', 'DNG Lens Info': '16 35 undef undef', 'Focal Length': 16.0, 'Exposure Time': 0.125, 'F Number': 8.0, 'ISO': 100.0, 'CFA Pattern 2': array([0, 1, 1, 2]), 'CFA Plane Color': array([0, 1, 2]), 'Black Level Repeat Dim': array([2, 2]), 'Black Level': array([1024, 1024, 1024, 1024]), 'White Level': array([15600]), 'Samples Per Pixel': 3, 'Active Area': array([  51,  158, 3804, 5792]), 'Orientation': 1, 'Camera Calibration Sig': 'com.adobe', 'Profile Calibration Sig': 'com.adobe', 'Calibration Illuminant 1': 17, 'Calibration Illuminant 2': 21, 'Color Matrix 1': array([[ 0.5309, -0.0229, -0.0336],
#        [-0.6241,  1.3265,  0.3337],
#        [-0.0817,  0.1215,  0.6664]]), 'Color Matrix 2': array([[ 0.4716,  0.0603, -0.083 ],
#        [-0.7798,  1.5474,  0.248 ],
#        [-0.1496,  0.1937,  0.6651]]), 'Camera Calibration 1': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Camera Calibration 2': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Analog Balance': array([ 1.,  1.,  1.]), 'Reduction Matrix 1': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Reduction Matrix 2': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Forward Matrix 1': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'Forward Matrix 2': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'As Shot Neutral': array([ 0.41307 ,  1.      ,  0.646465]), 'Baseline Exposure': 0.40000000000000002, 'Baseline Noise': 0.80000000000000004})}), InputTransform(M=array([[ 0.86482609, -0.01870308,  0.15387699],
#        [ 0.06217639,  1.14592314, -0.20809953],
#        [ 0.02503111, -0.1967513 ,  1.17172019]]), RGB_w=array([ 2.52706552,  1.        ,  1.36622751])), 'sRGB')" element with index "2".
# 2024-10-16 22:17:24,057 - 19717 - INFO - ParallelForMultiprocess: Processed "('/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2601.exr', CanonicalMapping({'EXIF': CanonicalMapping({'Make': 'Canon', 'Camera Model Name': 'Canon EOS 5D Mark II', 'Camera Serial Number': '330229410', 'Lens Model': 'EF16-35mm f/2.8L II USM', 'DNG Lens Info': '16 35 undef undef', 'Focal Length': 16.0, 'Exposure Time': 1.0, 'F Number': 8.0, 'ISO': 100.0, 'CFA Pattern 2': array([0, 1, 1, 2]), 'CFA Plane Color': array([0, 1, 2]), 'Black Level Repeat Dim': array([2, 2]), 'Black Level': array([1023, 1023, 1023, 1023]), 'White Level': array([15600]), 'Samples Per Pixel': 3, 'Active Area': array([  51,  158, 3804, 5792]), 'Orientation': 1, 'Camera Calibration Sig': 'com.adobe', 'Profile Calibration Sig': 'com.adobe', 'Calibration Illuminant 1': 17, 'Calibration Illuminant 2': 21, 'Color Matrix 1': array([[ 0.5309, -0.0229, -0.0336],
#        [-0.6241,  1.3265,  0.3337],
#        [-0.0817,  0.1215,  0.6664]]), 'Color Matrix 2': array([[ 0.4716,  0.0603, -0.083 ],
#        [-0.7798,  1.5474,  0.248 ],
#        [-0.1496,  0.1937,  0.6651]]), 'Camera Calibration 1': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Camera Calibration 2': array([[ 0.9603,  0.    ,  0.    ],
#        [ 0.    ,  1.    ,  0.    ],
#        [ 0.    ,  0.    ,  0.9664]]), 'Analog Balance': array([ 1.,  1.,  1.]), 'Reduction Matrix 1': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Reduction Matrix 2': array([[ 1.,  0.,  0.],
#        [ 0.,  1.,  0.],
#        [ 0.,  0.,  1.]]), 'Forward Matrix 1': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'Forward Matrix 2': array([[ 0.8924, -0.1041,  0.176 ],
#        [ 0.4351,  0.6621, -0.0972],
#        [ 0.0505, -0.1562,  0.9308]]), 'As Shot Neutral': array([ 0.41307 ,  1.      ,  0.646465]), 'Baseline Exposure': 0.40000000000000002, 'Baseline Noise': 0.80000000000000004})}), InputTransform(M=array([[ 0.86482609, -0.01870308,  0.15387699],
#        [ 0.06217639,  1.14592314, -0.20809953],
#        [ 0.02503111, -0.1967513 ,  1.17172019]]), RGB_w=array([ 2.52706552,  1.        ,  1.36622751])), 'sRGB')" element with index "3".
# 2024-10-16 22:17:25,183 - 19717 - INFO - GraphBatchMergeHDRI: Processing "NodeCreateBatches#97(None)" node...
# 2024-10-16 22:17:25,188 - 19717 - INFO - GraphBatchMergeHDRI: Processing "ParallelForMultiprocess#98(None)" node...
# 2024-10-16 22:17:25,196 - 19717 - INFO - ParallelForMultiprocess: Processing "GraphMergeHDRI(6)" node...
# 2024-10-16 22:51:16,171 - 19717 - INFO - ParallelForMultiprocess: Processed "/Users/kelsolaar/Documents/Development/colour-science/colour-hdri/colour_hdri/resources/colour-hdri-examples-datasets/frobisher_001/IMG_2598_5_HDR.exr" element with index "0".
# 2024-10-16 22:51:16,591 - 19717 - INFO - GraphPostMergeHDRI: Processing "NodeNormaliseExposure#107(None)" node...
# 2024-10-16 22:51:17,517 - 19717 - INFO - NormaliseExposure: Normalising factor: 0.43213167786598206
# 2024-10-16 22:51:19,188 - 19717 - INFO - GraphPostMergeHDRI: Processing "ParallelForMultiprocess#108(None)" node...
# 2024-10-16 22:51:19,190 - 19717 - INFO - ParallelForMultiprocess: Processing "NodeWritePreviewImage#109(None)" node...
